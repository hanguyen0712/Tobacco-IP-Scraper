# %%
import pandas as pd
from IPython.core.display import HTML
import numpy as np
import requests
import re
from bs4 import BeautifulSoup

pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### JTI

# %%
#load dataframe
jti = pd.read_excel("Japan Tobacco Inc.xlsx")
#create blank column to store image src
jti['Image'] = ''
#clean up goods/service column
for i in jti['GOODS / SERVICES']:
    if '34' in i:
        jti = jti.replace(i, '34')

# %%
#load txt file for query
file = BeautifulSoup(open("html_raw.txt", encoding = 'utf8').read(), "lxml")

# %%
for number in jti['APP. NUMBER']:
    for table in file.find_all('table'):
        #if the app number is present in the table:
        if number in str(table):
            #append src tag of the image to the current dataframe
            jti['Image'][jti.loc[jti['APP. NUMBER']==number].index[0]] = table.find_all('img')[0]['src']
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jti.head()
# Out:
#     APP. NUMBER   APP. DATE  \
# 0  4-2015-17485  03/07/2015
# 1  4-2015-24573  08/09/2015
# 2  4-2015-32071  16/11/2015
# 3  4-2016-03613  15/02/2016
# 4  4-2016-33622  26/10/2016
#
#                                                    TRADE MARK TM TYPE  \
# 0  MEVIUS FULLSTREAM STREAM FILTER C C [S], hÃ¬nh              Normal
# 1  HÃ¬nh                                                       Normal
# 2  MEVIUS LESS SMOKE SMELL LSS AIRSTREAM STREAM FILTER, hÃ¬nh  Normal
# 3  CASTER                                                      Normal
# 4  NOVA                                                        Normal
#
#    TM COLOR GOODS / SERVICES                 APPLICANT / RIGHT HOLDER  \
# 0  1         34               Japan Tobacco Inc. / Japan Tobacco Inc.
# 1  0         34               Japan Tobacco Inc. / Japan Tobacco Inc.
# 2  1         34               Japan Tobacco Inc.
# 3  0         34               Japan Tobacco Inc. / Japan Tobacco Inc.
# ...

# %%
HTML(jti.to_html(escape=False ,formatters=dict(image=jti['Image'])))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>APP. NUMBER</th>
#       <th>APP. DATE</th>
#       <th>TRADE MARK</th>
#       <th>TM TYPE</th>
#       <th>TM COLOR</th>
#       <th>GOODS / SERVICES</th>
#       <th>APPLICANT / RIGHT HOLDER</th>
#       <th>CHUKAN CODE</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4-2015-17485</td>
#       <td>03/07/2015</td>
#       <td>MEVIUS FULLSTREAM STREAM FILTER C C [S], hÃ¬nh</td>
#       <td>Normal</td>
#       <td>1</td>
#       <td>34</td>
#       <td>Japan Tobacco Inc. / Japan Tobacco Inc.</td>
#       <td>(31/07/2015) 221: Notification for Acceptance of Application  (15/08/2017) 151: Registration and Publication Fee Receipt  (31/07/2017) 251: Notification on Grant</td>
#       <td><img border="0" src="http://iplib.noip.gov.vn//IPDLIMG/20153/33058661Pictu001.jpg" width="150"/></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### BAT

# %%
#load dataframe
bat = pd.read_excel("British American Tobacco.xlsx")
#create blank column to store image src
bat['Image'] = ''
#clean up goods/service column
for i in bat['GOODS / SERVICES']:
    if '34' in i:
        bat = bat.replace(i, '34')

# %%
for number in bat['APP. NUMBER']:
    for table in file.find_all('table'):
        #if the app number is present in the table:
        if number in str(table):
            #append src tag of the image to the current dataframe
            bat['Image'][bat.loc[bat['APP. NUMBER']==number].index[0]] = table.find_all('img')[0]['src']
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
HTML(bat.to_html(escape=False ,formatters=dict(image=bat['Image'])))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>APP. NUMBER</th>
#       <th>APP. DATE</th>
#       <th>TRADE MARK</th>
#       <th>TM TYPE</th>
#       <th>TM COLOR</th>
#       <th>GOODS / SERVICES</th>
#       <th>APPLICANT / RIGHT HOLDER</th>
#       <th>CHUKAN CODE</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4-2015-02508</td>
#       <td>29/01/2015</td>
#       <td>nano CARBON, hÃ¬nh</td>
#       <td>Normal</td>
#       <td>0</td>
#       <td>34</td>
#       <td>British American Tobacco (Brands) Inc.</td>
# ...

# %% [markdown]
# ### PMI

# %%
#load dataframe
pmi = pd.read_excel("Philip Morris.xlsx")
#create blank column to store image src
pmi['Image'] = ''
#clean up goods/service column
for i in pmi['GOODS / SERVICES']:
    if '34' in i:
        pmi = pmi.replace(i, '34')

# %%
for number in pmi['APP. NUMBER']:
    for table in file.find_all('table'):
        #if the app number is present in the table:
        if number in str(table):
            #append src tag of the image to the current dataframe
            pmi['Image'][pmi.loc[pmi['APP. NUMBER']==number].index[0]] = table.find_all('img')[0]['src']
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
HTML(pmi.to_html(escape=False ,formatters=dict(image=pmi['Image'])))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>APP. NUMBER</th>
#       <th>APP. DATE</th>
#       <th>TRADE MARK</th>
#       <th>TM TYPE</th>
#       <th>TM COLOR</th>
#       <th>GOODS / SERVICES</th>
#       <th>APPLICANT / RIGHT HOLDER</th>
#       <th>CHUKAN CODE</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4-2015-26281</td>
#       <td>24/09/2015</td>
#       <td>AQUA SPRAY</td>
#       <td>Normal</td>
#       <td>0</td>
#       <td>34</td>
#       <td>Philip Morris Products S.A.</td>
#       <td>(30/11/2015) 221: Notification for Acceptance of Application  (19/06/2018) 143: Request for Notificaiton on Substantive Examination Results  (09/10/2015) 159: Submission the Priority Document  (25/09/2015) 101: Applicant self request for amendment application  (24/05/2018) 243: Notification on Substantive Examination Result (Refusal)</td>
# ...

# %% [markdown]
# ### Concatenate 3 dataframes

# %%
mainframe = pd.concat([jti, bat, pmi], ignore_index=True)
mainframe
# Out:
#       APP. NUMBER   APP. DATE  \
# 0    4-2015-17485  03/07/2015
# 1    4-2015-24573  08/09/2015
# 2    4-2015-32071  16/11/2015
# 3    4-2016-03613  15/02/2016
# 4    4-2016-33622  26/10/2016
# 5    4-2017-09591  13/04/2017
# 6    4-2017-19641  29/06/2017
# 7    4-2018-39531  12/11/2018
# 8    4-2018-41862  28/11/2018
# 9    4-2018-43530  10/12/2018
# 10   4-2015-02508  29/01/2015
# 11   4-2015-05379  12/03/2015
# 12   4-2015-05380  12/03/2015
# 13   4-2015-06913  27/03/2015
# 14   4-2015-06924  27/03/2015
# 15   4-2015-08644  13/04/2015
# 16   4-2015-10043  23/04/2015
# 17   4-2015-10780  05/05/2015
# 18   4-2015-13986  02/06/2015
# 19   4-2015-15181  12/06/2015
# 20   4-2015-15182  12/06/2015
# 21   4-2015-15183  12/06/2015
# 22   4-2015-15184  12/06/2015
# 23   4-2015-15185  12/06/2015
# 24   4-2015-15186  12/06/2015
# 25   4-2015-19074  20/07/2015
# 26   4-2015-19075  20/07/2015
# 27   4-2015-19076  20/07/2015
# 28   4-2015-20926  06/08/2015
# 29   4-2015-21802  14/08/2015
# ...

# %%
#export to excel file
mainframe.to_excel("main_data.xlsx")
